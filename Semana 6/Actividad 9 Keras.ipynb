# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow import keras
from tensorflow.keras import layers

# Cargar los datos
data = pd.read_csv('bank-additional-full.csv', delimiter=';')

# Convertir la variable objetivo 'y' a numérica
data['y'] = (data['y'] == 'yes').astype(int)

# Seleccionar solo las variables numéricas
numeric_columns = ['duration', 'pdays', 'previous', 'emp.var.rate', 
                    'euribor3m', 'nr.employed']
X = data[numeric_columns]
y = data['y']

# Normalizar las características
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Dividir los datos
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Crear el modelo
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dense(32, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(1)  # Sin función de activación para regresión
])

# Compilar el modelo
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# Entrenar el modelo
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=1)

# Evaluar el modelo
test_loss, test_mae = model.evaluate(X_test, y_test, verbose=0)
print(f"Error Absoluto Medio en el conjunto de prueba: {test_mae:.4f}")

# Hacer predicciones
predictions = model.predict(X_test)

# Mostrar algunas predicciones
print("\nAlgunas predicciones:")
for i in range(5):
    print(f"Valor real: {y_test.iloc[i]:.0f}, Valor predicho: {predictions[i][0]:.4f}")
# Out:
# c:\Users\jaime\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0733 - mean_absolute_error: 0.1388 - val_loss: 0.0649 - val_mean_absolute_error: 0.1374
# Epoch 2/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0634 - mean_absolute_error: 0.1297 - val_loss: 0.0637 - val_mean_absolute_error: 0.1317
# Epoch 3/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0610 - mean_absolute_error: 0.1263 - val_loss: 0.0625 - val_mean_absolute_error: 0.1243
# Epoch 4/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0604 - mean_absolute_error: 0.1249 - val_loss: 0.0617 - val_mean_absolute_error: 0.1272
# Epoch 5/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0585 - mean_absolute_error: 0.1213 - val_loss: 0.0619 - val_mean_absolute_error: 0.1318
# Epoch 6/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0603 - mean_absolute_error: 0.1255 - val_loss: 0.0612 - val_mean_absolute_error: 0.1228
# Epoch 7/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0606 - mean_absolute_error: 0.1259 - val_loss: 0.0616 - val_mean_absolute_error: 0.1288
# Epoch 8/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0592 - mean_absolute_error: 0.1227 - val_loss: 0.0606 - val_mean_absolute_error: 0.1192
# Epoch 9/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0594 - mean_absolute_error: 0.1227 - val_loss: 0.0607 - val_mean_absolute_error: 0.1289
# Epoch 10/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0582 - mean_absolute_error: 0.1213 - val_loss: 0.0605 - val_mean_absolute_error: 0.1265
# Epoch 11/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0586 - mean_absolute_error: 0.1222 - val_loss: 0.0606 - val_mean_absolute_error: 0.1264
# Epoch 12/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0581 - mean_absolute_error: 0.1219 - val_loss: 0.0599 - val_mean_absolute_error: 0.1283
# Epoch 13/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0579 - mean_absolute_error: 0.1197 - val_loss: 0.0613 - val_mean_absolute_error: 0.1200
# Epoch 14/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0574 - mean_absolute_error: 0.1186 - val_loss: 0.0598 - val_mean_absolute_error: 0.1226
# Epoch 15/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0593 - mean_absolute_error: 0.1227 - val_loss: 0.0599 - val_mean_absolute_error: 0.1253
# Epoch 16/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0571 - mean_absolute_error: 0.1195 - val_loss: 0.0597 - val_mean_absolute_error: 0.1205
# Epoch 17/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0589 - mean_absolute_error: 0.1218 - val_loss: 0.0609 - val_mean_absolute_error: 0.1300
# Epoch 18/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0583 - mean_absolute_error: 0.1218 - val_loss: 0.0608 - val_mean_absolute_error: 0.1256
# Epoch 19/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0584 - mean_absolute_error: 0.1221 - val_loss: 0.0595 - val_mean_absolute_error: 0.1240
# Epoch 20/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0558 - mean_absolute_error: 0.1172 - val_loss: 0.0599 - val_mean_absolute_error: 0.1220
# Epoch 21/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0580 - mean_absolute_error: 0.1198 - val_loss: 0.0594 - val_mean_absolute_error: 0.1268
# Epoch 22/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0572 - mean_absolute_error: 0.1192 - val_loss: 0.0601 - val_mean_absolute_error: 0.1160
# Epoch 23/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0571 - mean_absolute_error: 0.1175 - val_loss: 0.0595 - val_mean_absolute_error: 0.1261
# Epoch 24/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0570 - mean_absolute_error: 0.1178 - val_loss: 0.0591 - val_mean_absolute_error: 0.1214
# Epoch 25/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0552 - mean_absolute_error: 0.1157 - val_loss: 0.0598 - val_mean_absolute_error: 0.1168
# Epoch 26/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0577 - mean_absolute_error: 0.1194 - val_loss: 0.0594 - val_mean_absolute_error: 0.1175
# Epoch 27/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0577 - mean_absolute_error: 0.1192 - val_loss: 0.0601 - val_mean_absolute_error: 0.1265
# Epoch 28/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0570 - mean_absolute_error: 0.1183 - val_loss: 0.0594 - val_mean_absolute_error: 0.1230
# Epoch 29/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0585 - mean_absolute_error: 0.1216 - val_loss: 0.0595 - val_mean_absolute_error: 0.1202
# Epoch 30/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0579 - mean_absolute_error: 0.1202 - val_loss: 0.0591 - val_mean_absolute_error: 0.1209
# Epoch 31/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0559 - mean_absolute_error: 0.1170 - val_loss: 0.0594 - val_mean_absolute_error: 0.1233
# Epoch 32/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0559 - mean_absolute_error: 0.1163 - val_loss: 0.0594 - val_mean_absolute_error: 0.1281
# Epoch 33/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0582 - mean_absolute_error: 0.1219 - val_loss: 0.0594 - val_mean_absolute_error: 0.1207
# Epoch 34/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0557 - mean_absolute_error: 0.1162 - val_loss: 0.0592 - val_mean_absolute_error: 0.1216
# Epoch 35/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0572 - mean_absolute_error: 0.1193 - val_loss: 0.0594 - val_mean_absolute_error: 0.1272
# Epoch 36/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0580 - mean_absolute_error: 0.1204 - val_loss: 0.0594 - val_mean_absolute_error: 0.1193
# Epoch 37/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0577 - mean_absolute_error: 0.1194 - val_loss: 0.0595 - val_mean_absolute_error: 0.1232
# Epoch 38/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0574 - mean_absolute_error: 0.1195 - val_loss: 0.0587 - val_mean_absolute_error: 0.1153
# Epoch 39/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0557 - mean_absolute_error: 0.1153 - val_loss: 0.0598 - val_mean_absolute_error: 0.1222
# Epoch 40/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0568 - mean_absolute_error: 0.1180 - val_loss: 0.0594 - val_mean_absolute_error: 0.1166
# Epoch 41/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0583 - mean_absolute_error: 0.1211 - val_loss: 0.0596 - val_mean_absolute_error: 0.1221
# Epoch 42/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0560 - mean_absolute_error: 0.1165 - val_loss: 0.0600 - val_mean_absolute_error: 0.1205
# Epoch 43/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0578 - mean_absolute_error: 0.1201 - val_loss: 0.0590 - val_mean_absolute_error: 0.1189
# Epoch 44/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0575 - mean_absolute_error: 0.1198 - val_loss: 0.0598 - val_mean_absolute_error: 0.1265
# Epoch 45/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0579 - mean_absolute_error: 0.1212 - val_loss: 0.0592 - val_mean_absolute_error: 0.1190
# Epoch 46/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0584 - mean_absolute_error: 0.1208 - val_loss: 0.0594 - val_mean_absolute_error: 0.1196
# Epoch 47/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0577 - mean_absolute_error: 0.1196 - val_loss: 0.0593 - val_mean_absolute_error: 0.1253
# Epoch 48/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0578 - mean_absolute_error: 0.1193 - val_loss: 0.0600 - val_mean_absolute_error: 0.1187
# Epoch 49/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0575 - mean_absolute_error: 0.1191 - val_loss: 0.0595 - val_mean_absolute_error: 0.1214
# Epoch 50/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0564 - mean_absolute_error: 0.1176 - val_loss: 0.0595 - val_mean_absolute_error: 0.1221
# Error Absoluto Medio en el conjunto de prueba: 0.1222
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# Algunas predicciones:
# Valor real: 0, Valor predicho: 0.0905
# Valor real: 0, Valor predicho: -0.0020
# Valor real: 0, Valor predicho: -0.0043
# Valor real: 0, Valor predicho: 0.0235
# Valor real: 0, Valor predicho: -0.0030

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Cargar los datos
data = pd.read_csv('bank-additional-full.csv', delimiter=';')

# Convertir la variable objetivo 'y' a numérica
data['y'] = (data['y'] == 'yes').astype(int)

# Seleccionar solo las variables numéricas
numeric_columns = ['duration', 'pdays', 'previous', 'emp.var.rate', 
                    'euribor3m', 'nr.employed']
X = data[numeric_columns]
y = data['y']

# Normalizar las características
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Dividir los datos
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Modelo de regresión
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dense(32, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(1)  # Sin activación para regresión
])

# Compilar el modelo
model.compile(optimizer='adam', loss='mean_squared_error')

# Entrenar el modelo
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=1)

# Predicciones
predictions = model.predict(X_test)

# Calcular métricas
mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, predictions)
r2 = r2_score(y_test, predictions)

print(f"MSE: {mse:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"R²: {r2:.4f}")
# Out:
# c:\Users\jaime\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0655 - val_loss: 0.0628
# Epoch 2/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0621 - val_loss: 0.0627
# Epoch 3/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0633 - val_loss: 0.0613
# Epoch 4/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0606 - val_loss: 0.0612
# Epoch 5/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0593 - val_loss: 0.0608
# Epoch 6/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0604 - val_loss: 0.0614
# Epoch 7/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0600 - val_loss: 0.0613
# Epoch 8/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0609 - val_loss: 0.0600
# Epoch 9/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0597 - val_loss: 0.0606
# Epoch 10/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0589 - val_loss: 0.0617
# Epoch 11/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0594 - val_loss: 0.0607
# Epoch 12/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0590 - val_loss: 0.0603
# Epoch 13/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0576 - val_loss: 0.0601
# Epoch 14/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0591 - val_loss: 0.0596
# Epoch 15/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0581 - val_loss: 0.0602
# Epoch 16/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0570 - val_loss: 0.0604
# Epoch 17/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0556 - val_loss: 0.0595
# Epoch 18/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0579 - val_loss: 0.0601
# Epoch 19/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0570 - val_loss: 0.0607
# Epoch 20/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0603 - val_loss: 0.0596
# Epoch 21/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0580 - val_loss: 0.0604
# Epoch 22/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0565 - val_loss: 0.0595
# Epoch 23/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0582 - val_loss: 0.0594
# Epoch 24/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0574 - val_loss: 0.0600
# Epoch 25/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0578 - val_loss: 0.0599
# Epoch 26/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0584 - val_loss: 0.0603
# Epoch 27/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0586 - val_loss: 0.0595
# Epoch 28/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0583 - val_loss: 0.0595
# Epoch 29/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0578 - val_loss: 0.0603
# Epoch 30/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0572 - val_loss: 0.0599
# Epoch 31/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0578 - val_loss: 0.0602
# Epoch 32/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0590 - val_loss: 0.0604
# Epoch 33/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0578 - val_loss: 0.0598
# Epoch 34/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0573 - val_loss: 0.0607
# Epoch 35/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0569 - val_loss: 0.0592
# Epoch 36/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0576 - val_loss: 0.0595
# Epoch 37/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0562 - val_loss: 0.0607
# Epoch 38/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.0586 - val_loss: 0.0591
# Epoch 39/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0556 - val_loss: 0.0599
# Epoch 40/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0562 - val_loss: 0.0592
# Epoch 41/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0566 - val_loss: 0.0596
# Epoch 42/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0571 - val_loss: 0.0594
# Epoch 43/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0562 - val_loss: 0.0591
# Epoch 44/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0567 - val_loss: 0.0594
# Epoch 45/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0577 - val_loss: 0.0597
# Epoch 46/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0566 - val_loss: 0.0600
# Epoch 47/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0567 - val_loss: 0.0593
# Epoch 48/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0578 - val_loss: 0.0594
# Epoch 49/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0568 - val_loss: 0.0592
# Epoch 50/50
# 824/824 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0566 - val_loss: 0.0591
# 258/258 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MSE: 0.0589
# RMSE: 0.2426
# MAE: 0.1180
# R²: 0.4149
